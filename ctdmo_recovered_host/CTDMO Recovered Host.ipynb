# %%
import re
import struct
import binascii
import datetime
from collections import namedtuple

Header = namedtuple('Header', ['data_type', 'controller_id', 'inductive_id', 'num_bytes',
                    'mflm_flag', 'timestamp', 'block', 'crc'])

CTRecord = namedtuple('CTRecord', ['temp', 'cond', 'pressure', 'time', 'inductive_id'])

OFFSET = (datetime.datetime(2000, 1, 1) - datetime.datetime(1970, 1, 1)).total_seconds()

# %%
def decode_header(header):
    '''
    Header Description
    Offset    NumBytes    Value/Type    Description
    00        1           [0x01]        SOH, Start of Header
    01        2           [A-Z0-9]      Identifier for Instrument/DataType 
    03        5           [0-9]         ControllerID 
    08        2           [0-9]         Number of Instrument / Inductive ID 
    10        1           [_]           Spacer 5F hex
    11        4           [0-9A-F]      Number of Data Bytes, Hex Number (N bytes) 
    15*       1           [A-z0-9]      MFLM Processing Flag (u for unprocessed)
                                        OR HYPM Decimation Factor (A=1, Z=26) or HYPM d for decimated 
    16        8           [0-9A-F]      POSIX Timestamp of Controller, Hex Number 
    24        1           [_]           Spacer 5F hex
    25        2           [0-9A-F]      Block Number, HEX, 0 .. 255 (overflow) 
    27        1           [_]           Spacer 5F hex
    28        4           [0-9A-F]      CRC Checksum DataBytes CCITT-16 Reversed (0x8408) 
    32        1           [0x02]        STX, Start of Text 
    33        N                         Data Bytes
    33+       1           [0x03]        ETX, End of Text
    '''
    data_type = header[:2]
    controller_id = header[2:7]
    inductive_id = int(header[7:9])
    num_bytes = int(header[10:14], 16)
    mflm_flag = header[14:15]
    timestamp = int(header[15:23], 16)
    block = int(header[24:26], 16)
    crc = int(header[27:31], 16)
    return Header(data_type, controller_id, inductive_id, num_bytes, mflm_flag, timestamp, block, crc)


def decode_ct_records(chunk, inductive_id):
    sample_re = re.compile(r'[A-F0-9]{22}\r\n')
    records = []
    for record in sample_re.findall(chunk):
        temp = int(record[:5], 16)
        cond = int(record[5:10], 16)
        pressure, secs = struct.unpack('<HI', binascii.a2b_hex(record[10:22]))
#         pressure = int(record[12:14] + record[10:12], 16)
#         secs, = struct.unpack('<I', binascii.a2b_hex(record[14:22]))
        time = datetime.datetime.utcfromtimestamp(secs + OFFSET)
        records.append(CTRecord(temp, cond, pressure, time, inductive_id))
    return records

# %%
running = True
fh = open('CTD15907.DAT')
records = []

while running:
    flag = fh.read(1)
    if flag == '':
        break
    if flag == '\x01':
        # possible header
        header = decode_header(fh.read(31))
        body = fh.read(header.num_bytes)
        if header.data_type == 'CT':
            records.extend(decode_ct_records(body, header.inductive_id))
            
for r in records:
    print r
# Out:
# CTRecord(temp=225645, cond=50003, pressure=2786, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=67)
# CTRecord(temp=230348, cond=433201, pressure=2854, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=67)
# CTRecord(temp=190590, cond=398373, pressure=3245, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=67)
# CTRecord(temp=148912, cond=363598, pressure=4213, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=67)
# CTRecord(temp=144238, cond=367491, pressure=5167, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=67)
# CTRecord(temp=138187, cond=364528, pressure=6269, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=67)
# CTRecord(temp=138108, cond=364538, pressure=6351, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=67)
# CTRecord(temp=137844, cond=364831, pressure=6839, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=67)
# CTRecord(temp=144973, cond=361960, pressure=4597, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=29)
# CTRecord(temp=144936, cond=361730, pressure=4568, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=29)
# CTRecord(temp=138786, cond=364834, pressure=6137, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=29)
# CTRecord(temp=137998, cond=364608, pressure=6552, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=29)
# CTRecord(temp=137674, cond=364893, pressure=7039, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=29)
# CTRecord(temp=137801, cond=365108, pressure=7110, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=29)
# CTRecord(temp=137664, cond=364948, pressure=7107, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=29)
# CTRecord(temp=138851, cond=367024, pressure=7810, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=29)
# CTRecord(temp=230045, cond=432889, pressure=3236, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=20)
# CTRecord(temp=229781, cond=432770, pressure=3210, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=20)
# CTRecord(temp=229501, cond=432488, pressure=3270, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=20)
# CTRecord(temp=230178, cond=433096, pressure=3299, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=20)
# CTRecord(temp=230057, cond=433010, pressure=3292, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=20)
# CTRecord(temp=230369, cond=433284, pressure=3268, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=20)
# CTRecord(temp=230486, cond=433407, pressure=3277, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=20)
# CTRecord(temp=230402, cond=433251, pressure=3279, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=20)
# CTRecord(temp=167294, cond=378582, pressure=5260, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=19)
# CTRecord(temp=162221, cond=374105, pressure=5239, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=19)
# CTRecord(temp=150844, cond=364951, pressure=7099, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=19)
# CTRecord(temp=151542, cond=365471, pressure=6989, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=19)
# CTRecord(temp=151055, cond=365098, pressure=7000, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=19)
# CTRecord(temp=152723, cond=366314, pressure=6495, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=19)
# CTRecord(temp=153864, cond=367235, pressure=6293, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=19)
# CTRecord(temp=150759, cond=364905, pressure=7174, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=19)
# CTRecord(temp=157681, cond=370469, pressure=5508, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=54)
# CTRecord(temp=158647, cond=371207, pressure=5475, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=54)
# CTRecord(temp=151360, cond=365324, pressure=6964, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=54)
# CTRecord(temp=151287, cond=365279, pressure=6939, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=54)
# CTRecord(temp=151549, cond=365487, pressure=6931, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=54)
# CTRecord(temp=152429, cond=366118, pressure=6707, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=54)
# CTRecord(temp=152953, cond=366515, pressure=6461, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=54)
# CTRecord(temp=150632, cond=364763, pressure=6962, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=54)
# CTRecord(temp=154951, cond=368218, pressure=6044, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=62)
# CTRecord(temp=154589, cond=367915, pressure=6012, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=62)
# CTRecord(temp=147992, cond=362984, pressure=8150, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=62)
# CTRecord(temp=147824, cond=362826, pressure=8094, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=62)
# CTRecord(temp=147630, cond=362725, pressure=8082, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=62)
# CTRecord(temp=149359, cond=363867, pressure=7680, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=62)
# CTRecord(temp=150346, cond=364566, pressure=7325, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=62)
# CTRecord(temp=147500, cond=362627, pressure=8142, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=62)
# CTRecord(temp=201136, cond=407304, pressure=3908, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=60)
# CTRecord(temp=199328, cond=405921, pressure=3873, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=60)
# CTRecord(temp=196369, cond=403346, pressure=4222, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=60)
# CTRecord(temp=197238, cond=404045, pressure=4249, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=60)
# CTRecord(temp=195683, cond=402697, pressure=4243, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=60)
# CTRecord(temp=204218, cond=410045, pressure=4183, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=60)
# CTRecord(temp=200746, cond=407100, pressure=4158, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=60)
# CTRecord(temp=195633, cond=402720, pressure=4240, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=60)
# CTRecord(temp=154938, cond=368206, pressure=6129, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=52)
# CTRecord(temp=154203, cond=367606, pressure=6091, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=52)
# CTRecord(temp=147951, cond=363361, pressure=8544, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=52)
# CTRecord(temp=148246, cond=363522, pressure=8450, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=52)
# CTRecord(temp=148205, cond=363686, pressure=8426, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=52)
# CTRecord(temp=148008, cond=362937, pressure=7906, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=52)
# CTRecord(temp=149789, cond=364192, pressure=7522, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=52)
# CTRecord(temp=146660, cond=362269, pressure=8574, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=52)
# CTRecord(temp=184322, cond=392887, pressure=4731, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=15)
# CTRecord(temp=183110, cond=392002, pressure=4684, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=15)
# CTRecord(temp=158019, cond=370681, pressure=5517, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=15)
# CTRecord(temp=158229, cond=370871, pressure=5538, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=15)
# CTRecord(temp=158897, cond=371454, pressure=5535, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=15)
# CTRecord(temp=164998, cond=376488, pressure=5408, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=15)
# CTRecord(temp=161641, cond=373481, pressure=5299, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=15)
# CTRecord(temp=156601, cond=369560, pressure=5542, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=15)
# CTRecord(temp=230598, cond=433387, pressure=2832, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=56)
# CTRecord(temp=230436, cond=433243, pressure=2826, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=56)
# CTRecord(temp=230363, cond=433174, pressure=2819, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=56)
# CTRecord(temp=230353, cond=433203, pressure=2830, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=56)
# CTRecord(temp=230407, cond=433270, pressure=2838, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=56)
# CTRecord(temp=230549, cond=433388, pressure=2844, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=56)
# CTRecord(temp=230548, cond=433377, pressure=2847, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=56)
# CTRecord(temp=230789, cond=433590, pressure=2835, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=56)
# CTRecord(temp=219594, cond=50004, pressure=2795, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=57)
# CTRecord(temp=221544, cond=50004, pressure=2796, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=57)
# CTRecord(temp=218419, cond=50004, pressure=2796, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=57)
# CTRecord(temp=218568, cond=50004, pressure=2795, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=57)
# CTRecord(temp=219420, cond=50004, pressure=2796, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=57)
# CTRecord(temp=220121, cond=50005, pressure=2795, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=57)
# CTRecord(temp=221268, cond=50004, pressure=2796, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=57)
# CTRecord(temp=222941, cond=50005, pressure=2795, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=57)
# CTRecord(temp=146461, cond=362028, pressure=4355, time=datetime.datetime(2013, 7, 21, 18, 0, 1), inductive_id=26)
# CTRecord(temp=147193, cond=362724, pressure=4325, time=datetime.datetime(2013, 7, 21, 18, 15, 1), inductive_id=26)
# CTRecord(temp=142517, cond=367139, pressure=5409, time=datetime.datetime(2013, 7, 21, 18, 30, 1), inductive_id=26)
# CTRecord(temp=141552, cond=366458, pressure=5563, time=datetime.datetime(2013, 7, 21, 18, 45, 1), inductive_id=26)
# CTRecord(temp=140635, cond=365882, pressure=5718, time=datetime.datetime(2013, 7, 21, 19, 0, 1), inductive_id=26)
# CTRecord(temp=140420, cond=365642, pressure=5771, time=datetime.datetime(2013, 7, 21, 19, 15, 1), inductive_id=26)
# CTRecord(temp=139936, cond=365233, pressure=5705, time=datetime.datetime(2013, 7, 21, 19, 30, 1), inductive_id=26)
# CTRecord(temp=138026, cond=363962, pressure=5961, time=datetime.datetime(2013, 7, 21, 19, 45, 1), inductive_id=26)
# CTRecord(temp=137918, cond=366295, pressure=8125, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=67)
# CTRecord(temp=138347, cond=367673, pressure=9155, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=67)
# CTRecord(temp=138328, cond=367681, pressure=9158, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=67)
# CTRecord(temp=138325, cond=367594, pressure=9096, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=67)
# CTRecord(temp=138457, cond=368401, pressure=9938, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=67)
# CTRecord(temp=138058, cond=366924, pressure=8889, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=67)
# CTRecord(temp=138442, cond=367610, pressure=9136, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=67)
# CTRecord(temp=138637, cond=367899, pressure=9198, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=67)
# CTRecord(temp=138662, cond=367640, pressure=8744, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=29)
# CTRecord(temp=138287, cond=367711, pressure=9214, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=29)
# CTRecord(temp=138693, cond=367653, pressure=8784, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=29)
# CTRecord(temp=138684, cond=367646, pressure=8815, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=29)
# CTRecord(temp=138597, cond=367655, pressure=8971, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=29)
# CTRecord(temp=138347, cond=366679, pressure=8237, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=29)
# CTRecord(temp=138563, cond=367151, pressure=8512, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=29)
# CTRecord(temp=138784, cond=367314, pressure=8445, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=29)
# CTRecord(temp=230356, cond=433226, pressure=3320, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=20)
# CTRecord(temp=230429, cond=433310, pressure=3308, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=20)
# CTRecord(temp=230492, cond=433328, pressure=3325, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=20)
# CTRecord(temp=230529, cond=433378, pressure=3296, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=20)
# CTRecord(temp=230752, cond=433609, pressure=3296, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=20)
# CTRecord(temp=230484, cond=433339, pressure=3278, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=20)
# CTRecord(temp=230669, cond=433490, pressure=3294, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=20)
# CTRecord(temp=230589, cond=433435, pressure=3325, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=20)
# CTRecord(temp=147573, cond=362656, pressure=8089, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=19)
# CTRecord(temp=146487, cond=362312, pressure=8653, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=19)
# CTRecord(temp=148548, cond=363286, pressure=7794, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=19)
# CTRecord(temp=148992, cond=363642, pressure=7783, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=19)
# CTRecord(temp=150661, cond=364917, pressure=7658, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=19)
# CTRecord(temp=155858, cond=369101, pressure=6481, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=19)
# CTRecord(temp=152043, cond=365886, pressure=7056, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=19)
# CTRecord(temp=153697, cond=367145, pressure=6993, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=19)
# CTRecord(temp=149746, cond=364187, pressure=7443, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=54)
# CTRecord(temp=148519, cond=363266, pressure=7813, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=54)
# CTRecord(temp=150176, cond=364542, pressure=7483, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=54)
# CTRecord(temp=149966, cond=364332, pressure=7419, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=54)
# CTRecord(temp=150701, cond=364934, pressure=7418, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=54)
# CTRecord(temp=154706, cond=368050, pressure=6626, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=54)
# CTRecord(temp=153205, cond=366797, pressure=7044, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=54)
# CTRecord(temp=153455, cond=366990, pressure=7060, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=54)
# CTRecord(temp=144619, cond=361516, pressure=9017, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=62)
# CTRecord(temp=146674, cond=365430, pressure=9693, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=62)
# CTRecord(temp=145681, cond=361750, pressure=8985, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=62)
# CTRecord(temp=146088, cond=362050, pressure=8879, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=62)
# CTRecord(temp=146373, cond=362227, pressure=8867, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=62)
# CTRecord(temp=150639, cond=364888, pressure=7569, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=62)
# CTRecord(temp=149258, cond=363894, pressure=8216, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=62)
# CTRecord(temp=149194, cond=363832, pressure=8205, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=62)
# CTRecord(temp=192847, cond=400239, pressure=4341, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=60)
# CTRecord(temp=195236, cond=402351, pressure=4379, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=60)
# CTRecord(temp=195091, cond=402044, pressure=4362, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=60)
# CTRecord(temp=196025, cond=402969, pressure=4322, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=60)
# CTRecord(temp=193730, cond=401089, pressure=4320, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=60)
# CTRecord(temp=196566, cond=403487, pressure=4195, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=60)
# CTRecord(temp=195987, cond=402828, pressure=4263, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=60)
# CTRecord(temp=197038, cond=403663, pressure=4300, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=60)
# CTRecord(temp=146208, cond=365120, pressure=9767, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=52)
# CTRecord(temp=147993, cond=370044, pressure=10623, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=52)
# CTRecord(temp=147792, cond=365304, pressure=9573, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=52)
# CTRecord(temp=144965, cond=361912, pressure=9465, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=52)
# CTRecord(temp=145095, cond=361555, pressure=9403, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=52)
# CTRecord(temp=150361, cond=364700, pressure=7814, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=52)
# CTRecord(temp=148365, cond=363282, pressure=8576, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=52)
# CTRecord(temp=148548, cond=363399, pressure=8522, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=52)
# CTRecord(temp=155229, cond=368399, pressure=5783, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=15)
# CTRecord(temp=155479, cond=368666, pressure=5922, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=15)
# CTRecord(temp=156900, cond=369766, pressure=5807, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=15)
# CTRecord(temp=157269, cond=370106, pressure=5766, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=15)
# CTRecord(temp=158412, cond=371049, pressure=5760, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=15)
# CTRecord(temp=171539, cond=382051, pressure=5395, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=15)
# CTRecord(temp=165854, cond=377191, pressure=5600, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=15)
# CTRecord(temp=168894, cond=379667, pressure=5631, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=15)
# CTRecord(temp=230780, cond=433562, pressure=2836, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=56)
# CTRecord(temp=230729, cond=433515, pressure=2845, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=56)
# CTRecord(temp=230771, cond=433562, pressure=2853, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=56)
# CTRecord(temp=230689, cond=433493, pressure=2854, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=56)
# CTRecord(temp=230577, cond=433375, pressure=2853, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=56)
# CTRecord(temp=230757, cond=433538, pressure=2851, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=56)
# CTRecord(temp=230644, cond=433402, pressure=2850, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=56)
# CTRecord(temp=230812, cond=433558, pressure=2857, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=56)
# CTRecord(temp=221348, cond=50005, pressure=2795, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=57)
# CTRecord(temp=222678, cond=50005, pressure=2795, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=57)
# CTRecord(temp=221353, cond=50004, pressure=2795, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=57)
# CTRecord(temp=222689, cond=50004, pressure=2795, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=57)
# CTRecord(temp=225238, cond=50004, pressure=2795, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=57)
# CTRecord(temp=226071, cond=50004, pressure=2795, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=57)
# CTRecord(temp=227396, cond=50004, pressure=2795, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=57)
# CTRecord(temp=230149, cond=50004, pressure=2796, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=57)
# CTRecord(temp=138315, cond=364581, pressure=6260, time=datetime.datetime(2013, 7, 21, 20, 0, 1), inductive_id=26)
# CTRecord(temp=138035, cond=364564, pressure=6402, time=datetime.datetime(2013, 7, 21, 20, 15, 1), inductive_id=26)
# CTRecord(temp=138202, cond=364537, pressure=6296, time=datetime.datetime(2013, 7, 21, 20, 30, 1), inductive_id=26)
# CTRecord(temp=138297, cond=364511, pressure=6240, time=datetime.datetime(2013, 7, 21, 20, 45, 1), inductive_id=26)
# CTRecord(temp=138251, cond=364565, pressure=6337, time=datetime.datetime(2013, 7, 21, 21, 0, 1), inductive_id=26)
# CTRecord(temp=138908, cond=364709, pressure=6063, time=datetime.datetime(2013, 7, 21, 21, 15, 1), inductive_id=26)
# CTRecord(temp=138720, cond=364568, pressure=6128, time=datetime.datetime(2013, 7, 21, 21, 30, 1), inductive_id=26)
# CTRecord(temp=138241, cond=364244, pressure=6124, time=datetime.datetime(2013, 7, 21, 21, 45, 1), inductive_id=26)
