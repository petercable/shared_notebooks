# %%
# %matplotlib inline
# import seaborn as sbs
import xarray as xr
import pandas as pd
import datetime
import matplotlib

matplotlib.rcParams['figure.figsize'] = (15.0, 5.0)
matplotlib.rcParams['axes.formatter.useoffset'] = False

NTP_EPOCH = (datetime.datetime(1970,1,1) - datetime.datetime(1900,1,1)).total_seconds()

filepath = '20161202T155718-RS03CCAL-MJ03F-05-BOTPTA301-playback-botpt_nano_15s_precomputed/' + \
  'deployment0000_RS03CCAL-MJ03F-05-BOTPTA301-playback-botpt_nano_15s_precomputed_20140829T205945-20150519T221830.nc'

# %%
dataframe = xr.open_dataset(filepath, decode_times=False).to_dataframe()

# %%
dataframe['time'] = pd.to_datetime(dataframe.botsflu_time15s.values - NTP_EPOCH, unit='s')

# %%
dataframe = dataframe.set_index('time')

# %%
dataframe.botsflu_meandepth.plot()

# %%
dataframe.botsflu_5minrate.plot()  # cm/min

# %%
dataframe.botsflu_10minrate.plot()  # cm/hr
